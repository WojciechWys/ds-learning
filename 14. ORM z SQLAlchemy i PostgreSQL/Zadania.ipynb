# %%
"""
instalacja dockera
curl -fsSL https://get.docker.com | sudo sh

utworzenie bazy danych
docker run -d --name pg-mydb -e POSTGRES_DB=mydb -e POSTGRES_USER=user -e POSTGRES_PASSWORD=password -p 5432:5432 -v pg_mydb_data:/var/lib/postgresql/data postgres:16

ponowne uruchomienie bazy danych
docker start pg-mydb

connection string (do laczenia z baza):
postgresql://user:password@localhost:5432/mydb
"""

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import sessionmaker
# Connection string format:
# postgresql://username:password@host:port/database_name
# Dla lokalnego PostgreSQL
engine = create_engine(
'postgresql://user:password@localhost:5432/mydb',
echo=True # Wypisuje wygenerowane SQL (przydatne do nauki)
)
# Dla SQLite (testowo, bez instalacji PostgreSQL)
# engine = create_engine('sqlite:///datascience.db', echo=True)
# Baza klas dla modeli
Base = declarative_base()
# Session factory - fabryka sesji (połączeń)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
# Sprawdzenie połączenia
try:
    connection = engine.connect()
    print("✅ Połączenie z bazą danych udane!")
    connection.close()
except Exception as e:
    print(f"❌ Błąd połączenia: {e}")
# Out:
# 2026-02-05 20:11:41,583 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-02-05 20:11:41,583 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-05 20:11:41,585 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-02-05 20:11:41,585 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-05 20:11:41,586 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-02-05 20:11:41,586 INFO sqlalchemy.engine.Engine [raw sql] {}
# ✅ Połączenie z bazą danych udane!
