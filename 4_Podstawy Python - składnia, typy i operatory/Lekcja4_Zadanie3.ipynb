# %%
ilosc_probek = 1000
trening = 0.7 * ilosc_probek
walidacja = 0.15 * ilosc_probek
test = 0.15 * ilosc_probek

suma = trening + walidacja + test
print(suma)

print("Rozmiary zbiorów: ", "treningowy: " + str(trening), "walidacja: " + str(walidacja), "testowy: " + str(test))
# Out:
# 1000.0
# Rozmiary zbiorów:  treningowy: 700.0 walidacja: 150.0 testowy: 150.0
