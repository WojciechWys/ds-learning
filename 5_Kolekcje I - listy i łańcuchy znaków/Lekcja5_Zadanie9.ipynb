# %%
measurements_list = [23, 24, 22, 150, 23, 25, -10, 24, 23]
measurements_list_without_outliers = [x for x in measurements_list if 20 < x < 30]
print(measurements_list_without_outliers)
# Out:
# [23, 24, 22, 23, 25, 24, 23]
