# %%
file_name = "model_results_2024_Q3.csv"
without_extension = file_name.replace(".csv", "")
list_without_extension = without_extension.split("_")
print(list_without_extension)
print("Rok w nazwie pliku to:",list_without_extension[2])
print("Kwartał w nazwie pliku to:",list_without_extension[3])
# Out:
# ['model', 'results', '2024', 'Q3']
# Rok w nazwie pliku to: 2024
# Kwartał w nazwie pliku to: Q3
