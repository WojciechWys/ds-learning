# %%
from pydoc import replace

column_list = [" Customer ID ", "TOTAL AMOUNT", " date "]
clean_column_list = [col.strip() for col in column_list]
print(clean_column_list)
lower_column_list = [col.lower() for col in clean_column_list]
print(lower_column_list)
underscore_column_list = [col.replace(" ","_") for col in lower_column_list]
print(underscore_column_list)
# Out:
# ['Customer ID', 'TOTAL AMOUNT', 'date']
# ['customer id', 'total amount', 'date']
# ['customer_id', 'total_amount', 'date']
