# %%
predictions_list = ['spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'spam']
print("Słowo SPAM wystąpiło tyle razy: ",predictions_list.count('spam'))
print("Słowo HAM wystąpiło tyle razy: ",predictions_list.count('ham'))
# Out:
# Słowo SPAM wystąpiło tyle razy:  4
# Słowo HAM wystąpiło tyle razy:  3

# %%
import numpy as np

np.unique(predictions_list, return_counts=True)
# Out:
# (array(['ham', 'spam'], dtype='<U4'), array([3, 4]))
