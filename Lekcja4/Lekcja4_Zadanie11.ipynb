# %%
learning_rate = 0.01
batch_size = 64
epochs = 100
dropout = 64

print("Sprawdzanie parametru learning_rate:")
if (0 < learning_rate <= 1):print("OK")
else:print("Błąd: Parametr nie spełnia wymagań")

# W IFie przy pomocy operatora & sprawdzamy, czy postać bitowa liczby w zmiennej batch_size
print("Sprawdzanie parametru batch_size")
if ((batch_size & (batch_size - 1)) == 0 and batch_size != 0):print("OK")
else:print("Błąd: Parametr nie spełnia wymagań")

print("Sprawdzanie parametru epochs")
if (0 < epochs < 1000):print("OK")
else:print("Błąd: Parametr nie spełnia wymagań")

print("Sprawdzanie parametru dropout")
if (0 < dropout <= 1):print("OK")
else:print("Błąd: Parametr nie spełnia wymagań")
# Out:
# Sprawdzanie parametru learning_rate:
# OK
# Sprawdzanie parametru batch_size
# OK
# Sprawdzanie parametru epochs
# OK
# Sprawdzanie parametru dropout
# Błąd: Parametr nie spełnia wymagań
